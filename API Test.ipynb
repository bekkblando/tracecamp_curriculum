# %%
import requests
import iexfinance
from youtube_transcript_api import YouTubeTranscriptApi
import os

# %%
os.environ['IEX_TOKEN']
# Out:
# 'sk_411d96648b644779824579a209303708'

# %%
token = "sk_411d96648b644779824579a209303708"
ticker = 'tsla'
url = F"https://cloud.iexapis.com/stable/stock/{ticker}/quote?token={token}"

# %%
requests.get(url).json()['latestPrice']
# Out:
# 234.34

# %%
secret = 'sk_411d96648b644779824579a209303708'

# %%
from iexfinance.stocks import Stock
stock = Stock(["APPL"])

# %%
stock.get_quote()
# Out:
# ---------------------------------------------------------------------------
# IEXQueryError                             Traceback (most recent call last)
# <ipython-input-11-c195c5228a2f> in <module>
# ----> 1 stock.get_quote()
#
# /usr/local/lib/python3.7/site-packages/iexfinance/stocks/base.py in get_quote(self, **kwargs)
#     799             Stocks Quote endpoint data
#     800         """
# --> 801         return self._get_endpoint("quote", params=kwargs)
#     802
#     803     def get_relevant(self, **kwargs):
#
# /usr/local/lib/python3.7/site-packages/iexfinance/stocks/base.py in _get_endpoint(self, endpoint, params, fmt_p, fmt_j, filter_)
#     101         self.endpoints = [endpoint]
#     102
# --> 103         data = self.fetch(fmt_j=fmt_j, fmt_p=no_pandas)
#     104         # IEX Cloud returns multiple symbol requests as as a list of dicts
#     105         # so convert to dict of dicts
#
# ...

# %%
YouTubeTranscriptApi.get_transcript("IT_eFZdjU9E", languages=['en'])
# Out:
# [{'text': 'you', 'start': 0.07, 'duration': 2.06},
#  {'text': "hi everyone it's Jerry let's have a look",
#   'start': 2.56,
#   'duration': 5.579},
#  {'text': 'at a game from round one of the 2019',
#   'start': 4.93,
#   'duration': 6.6},
#  {'text': 'alts box Norway chess tournament on the',
#   'start': 8.139,
#   'duration': 6.15},
#  {'text': "white end Magnus Carlsen and he's paired",
#   'start': 11.53,
#   'duration': 5.16},
#  {'text': 'against Vishy Anand this is their',
#   'start': 14.289,
#   'duration': 5.731},
#  {'text': 'armageddon game they drew their', 'start': 16.69, 'duration': 6.78},
#  {'text': 'classical game and so for the format of',
#   'start': 20.02,
#   'duration': 5.07},
#  {'text': "this tournament that's what sparked the",
#   'start': 23.47,
#   'duration': 4.62},
#  {'text': "Armageddon game here's a nice shot of",
#   'start': 25.09,
#   'duration': 5.52},
#  {'text': 'them in action photo courtesy of Leonard',
#   'start': 28.09,
# ...
